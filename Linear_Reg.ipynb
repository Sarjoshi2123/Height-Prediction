# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv('height-weight.csv')
df.head()
# Out:
#    Weight  Height
# 0      45     120
# 1      58     135
# 2      48     123
# 3      60     145
# 4      70     160

# %%
# Having a scatter plot
plt.scatter(df['Weight'], df['Height'])
plt.xlabel('Weight')
plt.ylabel('Height')
# Out:
# Text(0, 0.5, 'Height')

# %%
#Filtering out the dependent and the independent features
X = df[['Weight']]
y = df['Height']

# %%
X
# Out:
#     Weight
# 0       45
# 1       58
# 2       48
# 3       60
# 4       70
# 5       78
# 6       80
# 7       90
# 8       95
# 9       78
# 10      82
# 11      95
# 12     105
# 13     100
# 14      85
# 15      78
# 16      50
# 17      65
# 18      76
# 19      87
# 20      45
# 21      56
# 22      72

# %%
y
# Out:
# 0     120
# 1     135
# 2     123
# 3     145
# 4     160
# 5     162
# 6     163
# 7     175
# 8     182
# 9     170
# 10    176
# 11    182
# 12    175
# 13    183
# 14    170
# 15    177
# 16    140
# 17    159
# 18    150
# 19    167
# 20    129
# 21    140
# 22    160
# Name: Height, dtype: int64

# %%
# Train Test Split 
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.20,random_state=42)

# %%
X.shape
# Out:
# (23, 1)

# %%
X_train.shape
# Out:
# (18, 1)

# %%
X_test.shape
# Out:
# (5, 1)

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
X_train, X_test
# Out:
# (array([[ 1.73689094],
#         [-0.92026952],
#         [ 1.4542143 ],
#         [ 0.21043706],
#         [-1.48562281],
#         [ 1.17153765],
#         [-1.6552288 ],
#         [-0.80719886],
#         [-0.24184557],
#         [ 0.0973664 ],
#         [-1.37255215],
#         [-1.03334018],
#         [-0.12877492],
#         [ 0.88886101],
#         [ 0.43657837],
#         [ 0.60618436],
#         [ 0.71925502],
#         [ 0.32350772]]),
#  array([[ 0.21043706],
#         [ 0.21043706],
#         [-1.6552288 ],
#         [ 1.17153765],
#         [-0.52452222]]))

# %%
from sklearn.linear_model import LinearRegression
regression = LinearRegression()
regression.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
print("Slope or Cofficient :", regression.coef_)
print("Intercept :", regression.intercept_)
# Out:
# Slope or Cofficient : [17.03440872]
# Intercept : 157.5

# %%
plt.scatter(X_train, y_train)
plt.plot(X_train, regression.predict(X_train),'g')

# %%
#Getting the predicted values
y_pred = regression.predict(X_test)

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, root_mean_squared_error
mse = mean_squared_error(y_test, y_pred)
mae = mean_absolute_error(y_test, y_pred)
rmse = root_mean_squared_error(y_test, y_pred)
print(mse)
print(mae)
print(rmse)
# Out:
# 109.77592599051664
# 9.822657814519232
# 10.477400726827081

# %%
from sklearn.metrics import r2_score
r2 = r2_score(y_test, y_pred)
print(r2)
# Out:
# 0.776986986042344

# %%
# Out:
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
#Suppose for the new data point the weight is 80
scaled_weight = scaler.transform([[80]])
scaled_weight
# Out:
# d:\Python\venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# array([[0.32350772]])

# %%
print(regression.predict([scaled_weight[0]]))
# Out:
# [163.01076266]

# %%
#Plotting a scatter plot for the predictions
plt.scatter(y_test, y_pred)

# %%
#Residuals
residuals = y_test - y_pred
residuals
# Out:
# 15    15.915329
# 9      8.915329
# 0     -9.304156
# 8      4.543549
# 17    10.434926
# Name: Height, dtype: float64

# %%
import seaborn as sns
sns.displot(residuals,kind='kde') #-> this should have a shape like the normal distribution

# %%
#Scatter plot between the predicted value and the residuals should be distributed uniformly
plt.scatter(y_pred, residuals)
